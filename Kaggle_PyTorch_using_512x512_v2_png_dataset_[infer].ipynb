# %% [markdown]
# # Kaggle starter notebook on Google Lab

# %%
# !nvidia-smi

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# mount the drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install monai pydicom torchmetrics

# %% [markdown]
# ## Setup and Imports
